# %%
from langchain_ollama import ChatOllama
llm = ChatOllama(model="deepseek-r1:1.5b")
llm.invoke("What is the capital ")
# Out:
# Running cells with 'lang_project (Python 3.12.12)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n lang_project ipykernel --update-deps --force-reinstall'
